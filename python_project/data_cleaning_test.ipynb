# %%
import pandas as pd
import re
import cn2an


def c_df():
    
    # 讀取檔案、建立 dataframe 物件

    city_list = ['a', 'b', 'e', 'f', 'h']

    dataframe_list = []

    for i in range(len(city_list)):
        temp_df = pd.read_csv('land_data/' + city_list[i] + '_lvr_land_a.csv')
        dataframe_list.append(temp_df)
    
    df_a = dataframe_list[0]
    df_b = dataframe_list[1]
    df_e = dataframe_list[2]
    df_f = dataframe_list[3]
    df_h = dataframe_list[4]
    

def m_df():
    
    # 合併 dataframe 物件
    df_all = pd.concat([df_a, df_b, df_e, df_f, df_h], axis=0, ignore_index=True)
    
def fil_df():
    
    # 篩選【 主要用途 】 為 【 住家用 】
    df_housing = df_all.query("主要用途 == '住家用'")
    
    # 篩選【 建物型態 】 為 【 住宅大樓 】
    df_hous_building = df_housing[df_housing['建物型態'].apply(lambda x: True if re.search('^住宅大樓', x) else False)]
       
    # 抓出剩餘的 index
    index_list = []
    for i in df_hous_building.index:
        index_list.append(i)
    
    # 將樓層中文轉成數字(int)
    for j in index_list:
        df_hous_building['總樓層數'][j] = cn2an.transform(df_hous_building['總樓層數'][j], "cn2an")
        df_hous_building['總樓層數'][j] = int(df_hous_building['總樓層數'][j].replace("層", ""))
        
    # 篩選總樓層數大於等於十三層的資料
    df_layer = df_hous_building.query("總樓層數 >= 13")

    # 抓出剩餘的 index
    index2_list = []
    for i in df_layer.index:
        index2_list.append(i)

    # 將樓層從數字再轉回中文小寫
    for j in index2_list:
        df_layer['總樓層數'][j] = cn2an.an2cn(df_layer['總樓層數'][j], "low")
        df_layer['總樓層數'][j] = str(df_layer['總樓層數'][j]) + "層"
        
def output_csv():
    df_layer.to_csv('filter_a.csv')
    

if __name__ == "__main__":
    c_df()
    m_df()
    fil_df()
    output_csv()
# Out:
# <ipython-input-154-84057562d43a>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hous_building['總樓層數'][j] = cn2an.transform(df_hous_building['總樓層數'][j], "cn2an")
# <ipython-input-154-84057562d43a>:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fil_df()
# <ipython-input-154-84057562d43a>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hous_building['總樓層數'][j] = int(df_hous_building['總樓層數'][j].replace("層", ""))
# <ipython-input-154-84057562d43a>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_layer['總樓層數'][j] = cn2an.an2cn(df_layer['總樓層數'][j], "low")
# <ipython-input-154-84057562d43a>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_layer['總樓層數'][j] = str(df_layer['總樓層數'][j]) + "層"

# %%
import pandas as pd
import re
import cn2an

# %%
city_list = ['a', 'b', 'e', 'f', 'h']

dataframe_list = []

for i in range(len(city_list)):
    temp_df = pd.read_csv('land_data/' + city_list[i] + '_lvr_land_a.csv')
    dataframe_list.append(temp_df)
    
df_a = dataframe_list[0]
df_b = dataframe_list[1]
df_e = dataframe_list[2]
df_f = dataframe_list[3]
df_h = dataframe_list[4]
    
# 合併 dataframe 物件
    
df_all = pd.concat([df_a, df_b, df_e, df_f, df_h], axis=0, ignore_index=True)
df_all
# Out:
#                                        鄉鎮市區              交易標的  \
# 0     The villages and towns urban district  transaction sign
# 1                                       文山區      房地(土地+建物)+車位
# 2                                       文山區         房地(土地+建物)
# 3                                       文山區      房地(土地+建物)+車位
# 4                                       文山區         房地(土地+建物)
# ...                                     ...               ...
# 3850                                    大溪區                土地
# 3851                                    龍潭區                土地
# 3852                                    龍潭區         房地(土地+建物)
# 3853                                    龍潭區         房地(土地+建物)
# 3854                                    龍潭區                土地
#
#                                                土地位置建物門牌  \
# 0     land sector position building sector house num...
# 1                                臺北市文山區興隆路一段５５巷２７弄３１號七樓
# 2                                    臺北市文山區興隆路四段５２巷５號三樓
# 3                                      臺北市文山區指南路三段９７號五樓
# 4                                      臺北市文山區福興路８２巷３弄３號
# ...                                                 ...
# 3850                                          信義段2178地號
# 3851                                           健行段159地號
# 3852                                     桃園市龍潭區永安街４２之１號
# 3853                             桃園市龍潭區金龍路１１２巷３１５弄５７－５號
# 3854                                           和原段130地號
#
#                                 土地移轉總面積平方公尺  \
# 0     land shifting total area square meter
# 1                                     47.04
# 2                                      20.1
# 3                                      9.16
# 4                                     22.99
# ...                                     ...
# 3850                                  31.42
# 3851                                 299.04
# 3852                                  85.68
# 3853                                  94.22
# 3854                                2235.46
#
#                                    都市土地使用分區  \
# 0     the use zoning or compiles and checks
# 1                                         住
# 2                                         住
# 3                                         住
# 4                                         住
# ...                                     ...
# 3850                                    NaN
# 3851                                    NaN
# 3852                                    NaN
# 3853                                    NaN
# 3854                                    NaN
#
#                                  非都市土地使用分區                非都市土地使用編定  \
# 0     the non-metropolis land use district  non-metropolis land use
# 1                                      NaN                      NaN
# 2                                      NaN                      NaN
# 3                                      NaN                      NaN
# 4                                      NaN                      NaN
# ...                                    ...                      ...
# 3850                                山坡地保育區                   丙種建築用地
# 3851                                 一般農業區                     農牧用地
# 3852                                   鄉村區                   乙種建築用地
# 3853                                 一般農業區                   甲種建築用地
# 3854                                山坡地保育區                     農牧用地
#
#                                交易年月日                   交易筆棟數            移轉層次  \
# 0     transaction year month and day  transaction pen number  shifting level
# 1                            1110228               土地1建物2車位2              七層
# 2                            1110218               土地2建物1車位0              三層
# 3                            1110215               土地1建物1車位1              五層
# 4                            1110120               土地1建物1車位0              一層
# ...                              ...                     ...             ...
# 3850                         1110328               土地1建物0車位0             NaN
# 3851                         1110325               土地1建物0車位0             NaN
# 3852                         1110329               土地1建物1車位0               全
# 3853                         1110305               土地2建物1車位0               全
# 3854                         1110210               土地4建物0車位0             NaN
#
#       ...                車位類別                           車位移轉總面積(平方公尺)  \
# 0     ...  the berth category  berth shifting total area square meter
# 1     ...                坡道平面                                     0.0
# 2     ...                 NaN                                     0.0
# 3     ...                坡道機械                                    25.1
# 4     ...                 NaN                                     0.0
# ...   ...                 ...                                     ...
# 3850  ...                 NaN                                     0.0
# 3851  ...                 NaN                                     0.0
# 3852  ...                 NaN                                     0.0
# 3853  ...                 NaN                                     0.0
# 3854  ...                 NaN                                     0.0
#
#                           車位總價元  \
# 0     the berth total price NTD
# 1                             0
# 2                             0
# 3                       1800000
# 4                             0
# ...                         ...
# 3850                          0
# 3851                          0
# 3852                          0
# 3853                          0
# 3854                          0
#
#                                                      備註                   編號  \
# 0                                              the note        serial number
# 1                                                   NaN  RPROMLOJLHHGFAA07DA
# 2                                                   NaN  RPTQMLOJLHHGFAA47DA
# 3                                         陽台外推；夾層；其他增建；  RPUOMLRJLHHGFAA67DA
# 4                                                 其他增建；  RPSOMLOKKHHGFAA17DA
# ...                                                 ...                  ...
# 3850                                                NaN  RPUNMLRJMHHGFCH68EA
# 3851                                                NaN  RPOOMLRJMHHGFCH18EA
# 3852                              親友、員工、共有人或其他特殊關係間之交易；  RPQOMLRJMHHGFCH38EA
# 3853                                                NaN  RPRNMLMJMHHGFCH77DA
# 3854  和原段130257259地號每坪9000元計價和原段111地號總價款新台幣參拾萬元正親友、員...  RPQNMLRJMHHGFCH18DA
#
#        主建物面積 附屬建物面積   陽台面積   電梯 移轉編號
# 0        NaN    NaN    NaN  NaN  NaN
# 1     138.23  18.15  12.60    有  1.0
# 2      72.35   0.00  12.35    無  NaN
# 3      23.16   0.74   3.60    有  2.0
# 4      81.44   5.17   0.00    無  NaN
# ...      ...    ...    ...  ...  ...
# 3850    0.00   0.00   0.00    無  NaN
# 3851    0.00   0.00   0.00    無  NaN
# 3852  101.66   0.00   0.00    無  NaN
# 3853  218.63   0.00   2.32    無  NaN
# 3854    0.00   0.00   0.00    無  NaN
#
# [3855 rows x 33 columns]
